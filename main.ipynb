# %% [markdown]
# #### Порядок анализа данных и построение модели прескоринга
#
# у всех файлов, если не указано иначе, корневой каталог *src/*
#
# запускать каждый в отдельности.
# функционал запуска через main не реализован

# %% [markdown]
# 1. Чтение данных
#
# ```bash
# src/data/mdm_create_pickle.ipynb
# ```
#
# 2. Определения категории лизингополучателей
#
# ```bash
# preprocessing/preprocessing_accounts.ipynb
# ```
#
# 3. Очистка и предобработка данных фед. ресурса
#
# ```bash
# preprocessing/merge_and_clean.ipynb
# ```
#
# 4. Расчет фичей для обучающей и тестовой выборки target-class
#
# ```bash
# features/feature_engineering.ipynb
# ```
#
# 5. Расчет фичей на данных федерального ресурса MDM
#
# ```bash
# features/feature_engineering_mdm.ipynb
# ```
#
# 6. Анализ репрезентативности обучающей выборки
#
# ```bash
# features/feature_representativeness.ipynb
# ```
#
# 7. Анализ стабильности распределения фичей
#
# ```bash
# features/feature_distribution_stability.ipynb
# ```
#
# 8. Анализ метрик однофакторного анализа фичей
#
# ```bash
# features/feature_one_factor_analysis.ipynb
# ```
#
# 9. Анализ линейной зависимости между фичами
#
# ```bash
# features/feature_correlation.ipynb
# features/feature_multicollinear.ipynb
# ```
#
# #### Ветка модели MVP
#
# 10. MVP модель фед ресурса с использованием двух фичей: Количество договоров (всех закрытых и действующих) и Количество договоров c признаками плохого завершения
#
# ```bash
# MVP model/mvp_model.ipynb
# ```
#
# #### Ветка построение модели прескоринга
#
# 10. Создание списка прескоринга, используя фичу: Количество договоров (всех закрытых и действующих)
#
# ```bash
# prescoring/prescoring_part1.ipynb
# ```
#
# 11. Создание списка прескоринга с помощью нескольких фичей
#
# ```bash
# prescoring/prescoring_part2.ipynb
# ```
